# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', 500)

# %% [markdown]
# # Cleaning

# %% [markdown]
# ### Replace NA

# %%
df = pd.read_csv('train.csv')

df.drop(['Alley', 'PoolQC', 'PoolArea', 'MiscFeature', 'LotFrontage'], axis=1, inplace=True)
df['FireplaceQu'].fillna('No', inplace=True)
df['Fence'].fillna('No', inplace=True)
df.dropna(inplace=True)
df.reset_index(inplace=True, drop = True)

df.to_csv('data.csv', index=False)

# %%
x = 0

# %%
print(df.iloc[:, x].value_counts())
x+=1
# Out:
# 9600     23
# 7200     20
# 6000     16
# 8400     13
# 9000     12
#          ..
# 2500      1
# 10289     1
# 12243     1
# 1526      1
# 9717      1
# Name: LotArea, Length: 1000, dtype: int64

# %%
df.describe(include = 'all')
# Out:
#                  Id   MSSubClass MSZoning        LotArea Street LotShape  \
# count   1338.000000  1338.000000     1338    1338.000000   1338     1338
# unique          NaN          NaN        5            NaN      2        4
# top             NaN          NaN       RL            NaN   Pave      Reg
# freq            NaN          NaN     1066            NaN   1333      829
# mean     731.228700    56.136024      NaN   10706.294469    NaN      NaN
# std      421.779691    41.252576      NaN   10336.621126    NaN      NaN
# min        1.000000    20.000000      NaN    1300.000000    NaN      NaN
# 25%      366.250000    20.000000      NaN    7744.000000    NaN      NaN
# 50%      730.500000    50.000000      NaN    9600.000000    NaN      NaN
# 75%     1098.750000    70.000000      NaN   11760.750000    NaN      NaN
# max     1460.000000   190.000000      NaN  215245.000000    NaN      NaN
#
#        LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# count         1338      1338      1338      1338         1338       1338
# unique           4         2         5         3           25          9
# top            Lvl    AllPub    Inside       Gtl        NAmes       Norm
# freq          1206      1337       957      1265          209       1162
# mean           NaN       NaN       NaN       NaN          NaN        NaN
# std            NaN       NaN       NaN       NaN          NaN        NaN
# min            NaN       NaN       NaN       NaN          NaN        NaN
# 25%            NaN       NaN       NaN       NaN          NaN        NaN
# 50%            NaN       NaN       NaN       NaN          NaN        NaN
# 75%            NaN       NaN       NaN       NaN          NaN        NaN
# max            NaN       NaN       NaN       NaN          NaN        NaN
#
#        Condition2 BldgType HouseStyle  OverallQual  OverallCond    YearBuilt  \
# count        1338     1338       1338  1338.000000  1338.000000  1338.000000
# unique          8        5          8          NaN          NaN          NaN
# top          Norm     1Fam     1Story          NaN          NaN          NaN
# freq         1324     1138        657          NaN          NaN          NaN
# mean          NaN      NaN        NaN     6.219731     5.596413  1973.029148
# std           NaN      NaN        NaN     1.324472     1.078124    29.563540
# min           NaN      NaN        NaN     2.000000     2.000000  1880.000000
# 25%           NaN      NaN        NaN     5.000000     5.000000  1956.000000
# 50%           NaN      NaN        NaN     6.000000     5.000000  1976.000000
# 75%           NaN      NaN        NaN     7.000000     6.000000  2001.000000
# max           NaN      NaN        NaN    10.000000     9.000000  2010.000000
#
#         YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# count    1338.000000      1338     1338        1338        1338       1338
# unique           NaN         6        8          14          16          4
# top              NaN     Gable  CompShg     VinylSd     VinylSd       None
# freq             NaN      1037     1314         486         475        763
# mean     1985.668909       NaN      NaN         NaN         NaN        NaN
# std        20.296463       NaN      NaN         NaN         NaN        NaN
# min      1950.000000       NaN      NaN         NaN         NaN        NaN
# 25%      1968.000000       NaN      NaN         NaN         NaN        NaN
# 50%      1994.500000       NaN      NaN         NaN         NaN        NaN
# 75%      2004.000000       NaN      NaN         NaN         NaN        NaN
# max      2010.000000       NaN      NaN         NaN         NaN        NaN
#
#          MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# count   1338.000000      1338      1338       1338     1338     1338
# unique          NaN         4         4          5        4        4
# top             NaN        TA        TA      PConc       TA       TA
# freq            NaN       803      1183        620      594     1237
# mean     110.360239       NaN       NaN        NaN      NaN      NaN
# std      185.604816       NaN       NaN        NaN      NaN      NaN
# min        0.000000       NaN       NaN        NaN      NaN      NaN
# 25%        0.000000       NaN       NaN        NaN      NaN      NaN
# 50%        0.000000       NaN       NaN        NaN      NaN      NaN
# 75%      174.000000       NaN       NaN        NaN      NaN      NaN
# max     1600.000000       NaN       NaN        NaN      NaN      NaN
#
#        BsmtExposure BsmtFinType1   BsmtFinSF1 BsmtFinType2   BsmtFinSF2  \
# count          1338         1338  1338.000000         1338  1338.000000
# unique            4            6          NaN            6          NaN
# top              No          GLQ          NaN          Unf          NaN
# freq            887          402          NaN         1176          NaN
# mean            NaN          NaN   464.234679          NaN    49.218236
# std             NaN          NaN   458.792420          NaN   166.196584
# min             NaN          NaN     0.000000          NaN     0.000000
# 25%             NaN          NaN     0.000000          NaN     0.000000
# 50%             NaN          NaN   413.000000          NaN     0.000000
# 75%             NaN          NaN   733.000000          NaN     0.000000
# max             NaN          NaN  5644.000000          NaN  1474.000000
#
#           BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# count   1338.000000  1338.000000    1338      1338       1338       1338
# unique          NaN          NaN       4         5          2          5
# top             NaN          NaN    GasA        Ex          Y      SBrkr
# freq            NaN          NaN    1318       704       1277       1242
# mean     582.494768  1095.947683     NaN       NaN        NaN        NaN
# std      439.950528   405.554435     NaN       NaN        NaN        NaN
# min        0.000000   105.000000     NaN       NaN        NaN        NaN
# 25%      248.000000   819.750000     NaN       NaN        NaN        NaN
# 50%      489.000000  1021.500000     NaN       NaN        NaN        NaN
# 75%      815.750000  1324.000000     NaN       NaN        NaN        NaN
# max     2336.000000  6110.000000     NaN       NaN        NaN        NaN
#
#            1stFlrSF     2ndFlrSF  LowQualFinSF    GrLivArea  BsmtFullBath  \
# count   1338.000000  1338.000000   1338.000000  1338.000000   1338.000000
# unique          NaN          NaN           NaN          NaN           NaN
# top             NaN          NaN           NaN          NaN           NaN
# freq            NaN          NaN           NaN          NaN           NaN
# mean    1176.221973   357.141256      4.221973  1537.585202      0.438714
# std      386.644986   440.324982     40.712916   520.579960      0.515630
# min      438.000000     0.000000      0.000000   438.000000      0.000000
# 25%      894.000000     0.000000      0.000000  1160.000000      0.000000
# 50%     1098.000000     0.000000      0.000000  1480.000000      0.000000
# 75%     1414.000000   740.500000      0.000000  1791.500000      1.000000
# max     4692.000000  2065.000000    572.000000  5642.000000      2.000000
#
#         BsmtHalfBath     FullBath     HalfBath  BedroomAbvGr  KitchenAbvGr  \
# count    1338.000000  1338.000000  1338.000000   1338.000000   1338.000000
# unique           NaN          NaN          NaN           NaN           NaN
# top              NaN          NaN          NaN           NaN           NaN
# freq             NaN          NaN          NaN           NaN           NaN
# mean        0.060538     1.575486     0.402840      2.864723      1.029895
# std         0.241685     0.547570     0.504185      0.776677      0.174697
# min         0.000000     0.000000     0.000000      0.000000      1.000000
# 25%         0.000000     1.000000     0.000000      2.000000      1.000000
# 50%         0.000000     2.000000     0.000000      3.000000      1.000000
# 75%         0.000000     2.000000     1.000000      3.000000      1.000000
# max         2.000000     3.000000     2.000000      6.000000      3.000000
#
#        KitchenQual  TotRmsAbvGrd Functional   Fireplaces FireplaceQu  \
# count         1338   1338.000000       1338  1338.000000        1338
# unique           4           NaN          7          NaN           6
# top             TA           NaN        Typ          NaN          No
# freq           650           NaN       1254          NaN         591
# mean           NaN      6.550075        NaN     0.648729         NaN
# std            NaN      1.585071        NaN     0.645393         NaN
# min            NaN      3.000000        NaN     0.000000         NaN
# 25%            NaN      5.000000        NaN     0.000000         NaN
# 50%            NaN      6.000000        NaN     1.000000         NaN
# 75%            NaN      7.000000        NaN     1.000000         NaN
# max            NaN     12.000000        NaN     3.000000         NaN
#
#        GarageType  GarageYrBlt GarageFinish  GarageCars   GarageArea  \
# count        1338  1338.000000         1338  1338.00000  1338.000000
# unique          6          NaN            3         NaN          NaN
# top        Attchd          NaN          Unf         NaN          NaN
# freq          852          NaN          580         NaN          NaN
# mean          NaN  1978.596413          NaN     1.87145   501.449925
# std           NaN    24.773741          NaN     0.63428   186.761863
# min           NaN  1900.000000          NaN     1.00000   160.000000
# 25%           NaN  1962.000000          NaN     1.00000   377.500000
# 50%           NaN  1980.000000          NaN     2.00000   484.000000
# 75%           NaN  2002.000000          NaN     2.00000   583.000000
# max           NaN  2010.000000          NaN     4.00000  1418.000000
#
#        GarageQual GarageCond PavedDrive   WoodDeckSF  OpenPorchSF  \
# count        1338       1338       1338  1338.000000  1338.000000
# unique          5          5          3          NaN          NaN
# top            TA         TA          Y          NaN          NaN
# freq         1270       1287       1257          NaN          NaN
# mean          NaN        NaN        NaN    99.384903    47.782511
# std           NaN        NaN        NaN   127.537065    65.362562
# min           NaN        NaN        NaN     0.000000     0.000000
# 25%           NaN        NaN        NaN     0.000000     0.000000
# 50%           NaN        NaN        NaN     6.000000    28.000000
# 75%           NaN        NaN        NaN   174.500000    70.000000
# max           NaN        NaN        NaN   857.000000   547.000000
#
#         EnclosedPorch    3SsnPorch  ScreenPorch Fence       MiscVal  \
# count     1338.000000  1338.000000   1338.00000  1338   1338.000000
# unique            NaN          NaN          NaN     5           NaN
# top               NaN          NaN          NaN    No           NaN
# freq              NaN          NaN          NaN  1077           NaN
# mean        21.263827     3.585949     16.43423   NaN     42.932735
# std         60.843964    30.224622     58.05159   NaN    508.056255
# min          0.000000     0.000000      0.00000   NaN      0.000000
# 25%          0.000000     0.000000      0.00000   NaN      0.000000
# 50%          0.000000     0.000000      0.00000   NaN      0.000000
# 75%          0.000000     0.000000      0.00000   NaN      0.000000
# max        552.000000   508.000000    480.00000   NaN  15500.000000
#
#              MoSold       YrSold SaleType SaleCondition      SalePrice
# count   1338.000000  1338.000000     1338          1338    1338.000000
# unique          NaN          NaN        9             6            NaN
# top             NaN          NaN       WD        Normal            NaN
# freq            NaN          NaN     1158          1104            NaN
# mean       6.331839  2007.805680      NaN           NaN  186761.782511
# std        2.699437     1.330691      NaN           NaN   78913.847668
# min        1.000000  2006.000000      NaN           NaN   35311.000000
# 25%        5.000000  2007.000000      NaN           NaN  135000.000000
# 50%        6.000000  2008.000000      NaN           NaN  168500.000000
# 75%        8.000000  2009.000000      NaN           NaN  220000.000000
# max       12.000000  2010.000000      NaN           NaN  755000.000000
